# %% [markdown]
# <a href="https://colab.research.google.com/github/minecraftsteeveeboy-wq/IT612/blob/main/1-28.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %%writefile code.js
#
# const addTax = function(price, rate) {
#   return price + (price * rate);
# }
#
# console.log(addTax(1.99, 0.05));
# console.log(addTax(9.99, 0.01));
#
# const createBurner = function(secret, limit) {
#   if (secret === limit) {
#     return `Done`;
#   }
#   const decrementLimit = function(limit) {
#     limit = limit - 1;
#   }
#
#   return decrementLimit(limit);
# }
#
# const object = {
#   "key1", 1;
#   "key2", 2;
#   "key3", 3;
# }
#
# JSON.stringify(object);
# JSON.parse(object);
# Out:
# Overwriting code.js

# %%
# !node code.js
# Out:
# /content/code.js:17
#   "key1", 1;
#   ^^^^^^
#
# SyntaxError: Unexpected string
#     at wrapSafe (node:internal/modules/cjs/loader:1472:18)
#     at Module._compile (node:internal/modules/cjs/loader:1501:20)
#     at Module._extensions..js (node:internal/modules/cjs/loader:1613:10)
#     at Module.load (node:internal/modules/cjs/loader:1275:32)
#     at Module._load (node:internal/modules/cjs/loader:1096:12)
#     at Function.executeUserEntryPoint [as runMain] (node:internal/modules/run_main:164:12)
#     at node:internal/main/run_main_module:28:49
#
# Node.js v20.19.0
